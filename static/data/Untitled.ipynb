# %%
import pandas as pd
file = 'HBW-BirdLife_Checklist_Version_3.xlsx'

data = pd.read_excel(file)
data.columns = data.iloc[0]
data = data.drop(0)

import openpyxl

wb = openpyxl.load_workbook(file)
ws = wb.active

hyperlinks = []
for row in range(3,ws.max_row+1):
    hyperlinks.append(ws.cell(row=row, column=5)
                      .hyperlink.target.split('/')[-1])

data['hyperlink'] = hyperlinks

names = [
    'Order','Family name','Family','CommonName','ScientificName',
    'Authority','TaxonomicTreatment', 'IUCNRedListCategory','Synonyms', 
    'AlternativeCommonNames', 'TaxonomicNotes','TaxonomicSource', 'SISRecID','SpcRecID', 'Hyperlink'
]
data.columns = names
data.head()
# Out:
# /home/adminctic/Documentos/bioinformatic_project/venv/lib/python3.5/site-packages/openpyxl/worksheet/header_footer.py:49: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#               Order    Family name     Family      CommonName  \
# 1  STRUTHIONIFORMES  Struthionidae  Ostriches  Common Ostrich
# 2  STRUTHIONIFORMES  Struthionidae  Ostriches  Somali Ostrich
# 3  STRUTHIONIFORMES  Struthionidae  Ostriches             NaN
# 4  STRUTHIONIFORMES        Rheidae      Rheas    Greater Rhea
# 5  STRUTHIONIFORMES        Rheidae      Rheas     Lesser Rhea
#
#            ScientificName         Authority TaxonomicTreatment  \
# 1        Struthio camelus    Linnaeus, 1758                  R
# 2  Struthio molybdophanes   Reichenow, 1883                  R
# 3        Struthio camelus    Linnaeus, 1758                 NR
# 4          Rhea americana  (Linnaeus, 1758)                  R
# ...

# %%
data.columns
# Out:
# Index(['Order', 'Family name', 'Family', 'CommonName', 'ScientificName',
#        'Authority', 'TaxonomicTreatment', 'IUCNRedListCategory', 'Synonyms',
#        'AlternativeCommonNames', 'TaxonomicNotes', 'TaxonomicSource',
#        'SISRecID', 'SpcRecID', 'Hyperlink'],
#       dtype='object')

# %%
linkpath = 'http://datazone.birdlife.org/species/factsheet/'
#IUCNRedListCategory

# %%
import 
dbdir = 'sqlite:///'+os.path.abspath(os.getcwd()) + '/static/aves.db'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0efd0c1be703> in <module>
# ----> 1 dbdir = 'sqlite:///'+os.path.abspath(os.getcwd()) + '/static/aves.db'
#
# NameError: name 'os' is not defined

# %%
class Aves(db.Model):
    id = db.Column('id', db.Integer, primary_key = True)
    commonName = db.Column(db.String(100))
    scientificName = db.Column(db.String(100))  
    redList = db.Column(db.String(10))
    link = db.Column(db.String(20))

    def __init__(self, name, city, addr,pin):
        self.commonName = commonName
        self.scientificName = scientificName
        self.redList = redList
        self.link = link
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c148a45ef91e> in <module>
# ----> 1 class Aves(db.Model):
#       2     id = db.Column('id', db.Integer, primary_key = True)
#       3     commonName = db.Column(db.String(100))
#       4     scientificName = db.Column(db.String(100))
#       5     redList = db.Column(db.String(10))
#
# NameError: name 'db' is not defined

# %%
data.head()
# Out:
#               Order    Family name     Family      CommonName  \
# 1  STRUTHIONIFORMES  Struthionidae  Ostriches  Common Ostrich
# 2  STRUTHIONIFORMES  Struthionidae  Ostriches  Somali Ostrich
# 3  STRUTHIONIFORMES  Struthionidae  Ostriches             NaN
# 4  STRUTHIONIFORMES        Rheidae      Rheas    Greater Rhea
# 5  STRUTHIONIFORMES        Rheidae      Rheas     Lesser Rhea
#
#            ScientificName         Authority TaxonomicTreatment  \
# 1        Struthio camelus    Linnaeus, 1758                  R
# 2  Struthio molybdophanes   Reichenow, 1883                  R
# 3        Struthio camelus    Linnaeus, 1758                 NR
# 4          Rhea americana  (Linnaeus, 1758)                  R
# 5            Rhea pennata   d'Orbigny, 1834                  R
#
#   IUCNRedListCategory Synonyms                     AlternativeCommonNames  \
# 1                  LC      NaN                                        NaN
# ...

# %%
from flask_sqlalchemy import SQLAlchemy
from flask import Flask
import pandas as pd
import os

app = Flask(__name__)
app.config['SECRET_KEY'] = 'my_key'

dbdir = 'sqlite:///'+os.path.abspath(os.getcwd()) + '/static/aves.db'
app.config['SQLALCHEMY_DATABASE_URI'] = dbdir
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
db = SQLAlchemy(app)

# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-012ab3a6b187> in <module>
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
#https://www.tutorialspoint.com/flask/flask_sqlalchemy.htm
class Aves(db.Model):
    id = db.Column('id', db.Integer, primary_key = True)
    commonName = db.Column(db.String(100))
    scientificName = db.Column(db.String(100))  
    redList = db.Column(db.String(10))
    link = db.Column(db.String(20))

    def __init__(self, name, city, addr,pin):
        self.commonName = commonName
        self.scientificName = scientificName
        self.redList = redList
        self.link = link

def setdb():
    data = pd.read_csv('static/data/Birds.csv')
    for row in data.shape[0]:
        scientificName = data['ScientificName'].iloc[row]
        commonName = data['CommonName'].iloc[row]
        redList = data['IUCNRedListCategory'].iloc[row]
        link = data['Hyperlink'].iloc[row]
        data['commonName = commonName, scientificName = scientificName, redList = redList, link = link']
        aves = Aves( commonName = commonName, scientificName = scientificName, redList = redList, link = link)
        db.session.add(aves)
        db.session.commit()

# %%
db.create_all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Documentos/bioinformatic_project/venv/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~/Documentos/bioinformatic_project/venv/lib/python3.5/site-packages/sqlalchemy/pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~/Documentos/bioinformatic_project/venv/lib/python3.5/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~/Documentos/bioinformatic_project/venv/lib/python3.5/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
# ...

# %%
data.to_csv("Birds.csv", index=False)
data.tail()
# Out:
#                Order Family name    Family CommonName        ScientificName  \
# 13038  PASSERIFORMES  Thraupidae  Tanagers        NaN    Tangara cyanoptera
# 13039  PASSERIFORMES  Thraupidae  Tanagers        NaN      Tangara vassorii
# 13040  PASSERIFORMES  Thraupidae  Tanagers        NaN         Tangara velia
# 13041  PASSERIFORMES  Thraupidae  Tanagers        NaN  Tangara brasiliensis
# 13042  PASSERIFORMES  Thraupidae  Tanagers        NaN     Tangara cucullata
#
#                  Authority TaxonomicTreatment IUCNRedListCategory Synonyms  \
# 13038     (Swainson, 1834)                 NR                  NR      NaN
# 13039  (Boissonneau, 1840)                 NR                  NR      NaN
# 13040     (Linnaeus, 1758)                 NR                  NR      NaN
# 13041     (Linnaeus, 1766)                 NR                  NR      NaN
# 13042     (Swainson, 1834)                 NR                  NR      NaN
#
#       AlternativeCommonNames TaxonomicNotes  \
# ...
